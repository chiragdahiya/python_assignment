# %%
# necessary Imports
import pandas as pd
import matplotlib.pyplot as plt
import numpy as npxz  
import seaborn as sns
import numpy as np

# %%
data=pd.read_csv('insurance.csv')

# %%
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
data.shape
# Out:
# (1338, 7)

# %%
# Value counts for categorical data
print(data.sex.value_counts(),'\n',data.children.value_counts(),'\n',data.region.value_counts(),'\n',data.smoker.value_counts(),'\n')
# Out:
# male      676
# female    662
# Name: sex, dtype: int64
#  0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64
#  southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64
#  no     1064
# yes     274
# Name: smoker, dtype: int64

# %% [markdown]
# # replacing the categorical variable with numerical variables

# %%
data['sex']=data['sex'].map({'male':1,'female':0})
data['smoker']=data['smoker'].map({'yes':1,'no':0})
data['region']=data['region'].map({'southeast':0,'southwest':1,'northwest':2,'northeast':3})

# %%
data.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       1  16884.92400
# 1   18    1  33.770         1       0       0   1725.55230
# 2   28    1  33.000         3       0       0   4449.46200
# 3   33    1  22.705         0       0       2  21984.47061
# 4   32    1  28.880         0       0       2   3866.85520

# %% [markdown]
# # Exploratory Data Analysis

# %%
#Checking Age Distribution
plt.figure(figsize=(13,7))
sns.histplot(data.age, bins = 20, kde = False,color = 'blue')
plt.title('Age distribution')
plt.xlabel('Age')
plt.ylabel('Frequency of each age')
plt.show()

# %% [markdown]
# ***max number of people in a dataset have a age below 20.***

# %%
#chceking sex distribution
plt.figure(figsize=(13,7))
sns.countplot(x='sex',data=data)
plt.title("Gender Distribution")
# Out:
# Text(0.5, 1.0, 'Gender Distribution')

# %%
data.describe()
# Out:
#                age          sex          bmi     children       smoker  \
# count  1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean     39.207025     0.505232    30.663397     1.094918     0.204783
# std      14.049960     0.500160     6.098187     1.205493     0.403694
# min      18.000000     0.000000    15.960000     0.000000     0.000000
# 25%      27.000000     0.000000    26.296250     0.000000     0.000000
# 50%      39.000000     1.000000    30.400000     1.000000     0.000000
# 75%      51.000000     1.000000    34.693750     2.000000     0.000000
# max      64.000000     1.000000    53.130000     5.000000     1.000000
#
#             region       charges
# count  1338.000000   1338.000000
# mean      1.455157  13270.422265
# std       1.130197  12110.011237
# min       0.000000   1121.873900
# 25%       0.000000   4740.287150
# 50%       1.000000   9382.033000
# 75%       2.000000  16639.912515
# max       3.000000  63770.428010

# %% [markdown]
# ***male and female are almost same in number in data***

# %%
#checking BMI distribution
plt.figure(figsize=(13,7))
sns.histplot(data.bmi, bins = 20, kde = True,color = 'blue')
plt.title('bmi distribution')
plt.xlabel('bmi')
plt.ylabel('Frequency of each bmi')
plt.show()

# %% [markdown]
#  data is normal distribution.
# ***The majority of people have BMI in between 225 and 40 ,which is considered  as overweight could be a major factor in increasing a medical cost***

# %%
#checking children
plt.figure(figsize=(13,7))
sns.countplot(x='children',data=data)
plt.title("ratio of children")
# Out:
# Text(0.5, 1.0, 'ratio of children')

# %% [markdown]
# ***whenever we are trying to check one variable or feature at a one time is called univariate analysis***

# %%
#checking smokers
plt.figure(figsize=(13,7))
sns.countplot(x='smoker',data=data)
plt.title("no of smoker")
# Out:
# Text(0.5, 1.0, 'no of smoker')

# %%
#Checking Charges Distribution
plt.figure(figsize=(13,7))
sns.histplot(data.charges,bins = 20, kde = True, color = 'blue')
plt.title('charges Distribution')
plt.xlabel('charges')
plt.ylabel('Frequency of each charges')
plt.show()

# %% [markdown]
# ***maximum charges is between 2000 to 13000 , graph is positive skewed ,minimum charges are between 30000 to 40000 or less than 50000, there are no of people which arae negligible between range 5000 and 6000***

# %% [markdown]
# ***Most of the medical expenses are below 20000 ,with negligible number of patient haeving a medical expensive above 50000.***

# %% [markdown]
# # Bi-variate Analysis

# %%
#Relation between Gender and Smoker
plt.figure(figsize=(13,7))
sns.catplot(x='smoker',kind='count',hue='sex',data=data)
plt.xlabel('smoker')
plt.ylabel('count')
plt.title('Relation between Gender and Smoekr')
plt.show()

# %%
plt.figure(figsize=(13,7))
plt.title('Box plot for charges of women')
sns.boxplot(y='smoker',x = 'charges', data=data[(data.sex == 0)],orient='h')
# Out:
# <Axes: title={'center': 'Box plot for charges of women'}, xlabel='charges', ylabel='smoker'>

# %%
plt.figure(figsize=(13,7))
plt.title('Box plot for charges of women')
sns.boxplot(y='smoker',x = 'charges', data=data[(data.sex == 1)],orient='h')
# Out:
# <Axes: title={'center': 'Box plot for charges of women'}, xlabel='charges', ylabel='smoker'>

# %%
cor=data.corr()
cor
# Out:
#                age       sex       bmi  children    smoker    region   charges
# age       1.000000 -0.020856  0.109272  0.042469 -0.025019  0.006308  0.299008
# sex      -0.020856  1.000000  0.046371  0.017163  0.076185 -0.012816  0.057292
# bmi       0.109272  0.046371  1.000000  0.012759  0.003750 -0.262754  0.198341
# children  0.042469  0.017163  0.012759  1.000000  0.007673  0.001205  0.067998
# smoker   -0.025019  0.076185  0.003750  0.007673  1.000000 -0.038873  0.787251
# region    0.006308 -0.012816 -0.262754  0.001205 -0.038873  1.000000 -0.039473
# charges   0.299008  0.057292  0.198341  0.067998  0.787251 -0.039473  1.000000

# %%
plt.figure(figsize=(13, 7))
sns.heatmap(cor, annot = True, cmap = 'BuGn_r')
# Out:
# <Axes: >

# %% [markdown]
# ***by observing above plot we can say that smokers has more medical expenses so it has a high impact on insurance cahrge followed by ageand bmi whereas region,gender and children has no impact**

# %%
#relation between smookers and age distribution
plt.figure(figsize=(13,7))
sns.catplot(x='smoker',y='age',kind='swarm',data=data)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 7.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ***From the above graph,we can observe that there is significant number of smoker at the age 19**

# %% [markdown]
# # Multi-Variate Analysis

# %% [markdown]
# whenever we have more than two variable

# %%
plt.figure(figsize=(13,7))
sns.scatterplot(x='age',y='charges',data=data[(data.smoker==0)])
plt.title('scatter plot for charges of non smoker ')
plt.xlabel('Age')
plt.ylabel('Medical expenditure')
plt.show()

# %% [markdown]
# ***majority of the points show that medical expensis increases with the age  which may due to the fact that older people are more prone to illness. But there are some outliers which shows other illness or expenses whic may lead to increase in medical expenditure***

# %%
plt.figure(figsize=(13,7))
sns.scatterplot(x='age',y='charges',data=data[(data.smoker==1)])
plt.title('scatter plot for charges of  smoker ')
plt.xlabel('Age')
plt.ylabel('Medical expenditure')
plt.show()

# %% [markdown]
# * In this graph there are two segments,one with high medical expenditure which may due to the smoking related illness and other with low medical expense which may due to age related illness.
# Now ,in order to get more clear we can combine both the graphs*

# %%
# Age charge Distribution 
plt.figure(figsize=(13,7))
sns.lmplot(x='age',y='charges',data=data,hue='smoker')
plt.xlabel("Age")
plt.ylabel("Medical Expenses")
plt.show()

# %% [markdown]
# *Now,we can clearly understand the variation in charges with respect to age and smoking habits. The medical expenses of smokers is higher than no-smoker irrespective of age.in non-smokers,the cost of treatment increases with age which is obvious.*

# %%
plt.figure(figsize=(14,8))
sns.distplot(data[(data.bmi>30)]['charges'])
plt.title("Charges distribution for obese people")
plt.xlabel("Medical expenditure")
plt.show()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_2540\2185170266.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[(data.bmi>30)]['charges'])

# %% [markdown]
# Therefore ,people with Bmi less than 30 are spending less where as people with Bmi more than 300 are  spending more

# %% [markdown]
# # Feature Selection

# %%
#droping irrelevant column
data.drop('region',axis = 1,inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[129], line 2
#       1 #droping irrelevant column
# ----> 2 data.drop('region',axis = 1,inplace = True)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
# ...

# %%
data.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       1  16884.92400
# 1   18    1  33.770         1       0       0   1725.55230
# 2   28    1  33.000         3       0       0   4449.46200
# 3   33    1  22.705         0       0       2  21984.47061
# 4   32    1  28.880         0       0       2   3866.85520

# %% [markdown]
# # Model Building & Evaluation

# %% [markdown]
# # Linear Regression

# %%
x=data.drop('charges',axis=1)
y=data.charges

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=2)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((1003, 6), (335, 6), (1003,), (335,))

# %%
#linear regression
from sklearn.linear_model import LinearRegression
reg =LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#making prediction
y_pred=reg.predict(x_test)

# %%
#model evaluation
from sklearn import metrics
print('MAE:',metrics.mean_absolute_error(y_test,y_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
print("R2 Score:",metrics.r2_score(y_test,y_pred))
# Out:
# MAE: 4174.729558049057
# RMSE: 6135.665214206238
# R2 Score: 0.7505625600466854

# %% [markdown]
# # Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg=PolynomialFeatures(degree=2)
poly_reg
# Out:
# PolynomialFeatures()

# %%
#transforming the feature to higher degree
x_train_poly=poly_reg.fit_transform(x_train)

#splitting the data
x_train,x_test,y_train,y_test=train_test_split(x_train_poly,y_train,test_size=0.2,random_state=42)

# %%
#train the model
plr=LinearRegression()
plr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred_plr=plr.predict(x_test)

# %%
#Model Evaluation
from sklearn import metrics
print('MAE:',metrics.mean_absolute_error(y_test,y_pred_plr))
print('RMSE',np.sqrt(metrics.mean_squared_error(y_test,y_pred_plr)))
print('R2 Score:',metrics.r2_score(y_test,y_pred_plr))
# Out:
# MAE: 3179.4976066169156
# RMSE 5207.793216818944
# R2 Score: 0.769549061300814

# %% [markdown]
# result:My model is able to explain 80% of the total data set

# %%
#input the values
age=54
sex=1
bmi=45
children=0
smoker=0
region=1

# %%
#predicting the price using random forest regression
charge=reg.predict([[age,sex,bmi,children,smoker,region]])
print("The charge of this new patient is $",charge[0])
# Out:
# The charge of this new patient is $ 39775.5715221587
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
